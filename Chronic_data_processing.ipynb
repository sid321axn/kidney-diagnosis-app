# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('chronic.csv')

# %%
df.head()
# Out:
#   Age  BP specific_gravity Albumin sugar     RBC        PC         PCC  \
# 0  48  80             1.02       1     0       ?    normal  notpresent
# 1   7  50             1.02       4     0       ?    normal  notpresent
# 2  62  80             1.01       2     3  normal    normal  notpresent
# 3  48  70            1.005       4     0  normal  abnormal     present
# 4  51  80             1.01       2     0  normal    normal  notpresent
#
#      bacteria Blood_Gluc_rand  ...  packed_cell_volume wbc_cnt rbc_cnt  htn  \
# 0  notpresent             121  ...                  44    7800     5.2  yes
# 1  notpresent               ?  ...                  38    6000       ?   no
# 2  notpresent             423  ...                  31    7500       ?   no
# 3  notpresent             117  ...                  32    6700     3.9  yes
# 4  notpresent             106  ...                  35    7300     4.6   no
#
#   diabetes CAD apetite pedal_edema anemia class
# ...

# %%
df.isna().sum()
# Out:
# Age                   0
# BP                    0
# specific_gravity      0
# Albumin               0
# sugar                 0
# RBC                   0
# PC                    0
# PCC                   0
# bacteria              0
# Blood_Gluc_rand       0
# Blood_Urea            0
# Serum_Cr              0
# sodium                0
# potassium             0
# hemoglobin            0
# packed_cell_volume    0
# wbc_cnt               0
# rbc_cnt               0
# htn                   0
# diabetes              0
# CAD                   0
# apetite               0
# pedal_edema           0
# anemia                0
# class                 0
# dtype: int64

# %%
df=df.replace('?', np.nan)

# %%
df
# Out:
#     Age   BP specific_gravity Albumin sugar       RBC        PC         PCC  \
# 0    48   80             1.02       1     0       NaN    normal  notpresent
# 1     7   50             1.02       4     0       NaN    normal  notpresent
# 2    62   80             1.01       2     3    normal    normal  notpresent
# 3    48   70            1.005       4     0    normal  abnormal     present
# 4    51   80             1.01       2     0    normal    normal  notpresent
# 5    60   90            1.015       3     0       NaN       NaN  notpresent
# 6    68   70             1.01       0     0       NaN    normal  notpresent
# 7    24  NaN            1.015       2     4    normal  abnormal  notpresent
# 8    52  100            1.015       3     0    normal  abnormal     present
# 9    53   90             1.02       2     0  abnormal  abnormal     present
# 10   50   60             1.01       2     4       NaN  abnormal     present
# ...

# %%
df.isna().sum()
# Out:
# Age                     9
# BP                     12
# specific_gravity       47
# Albumin                46
# sugar                  49
# RBC                   152
# PC                     65
# PCC                     4
# bacteria                4
# Blood_Gluc_rand        44
# Blood_Urea             19
# Serum_Cr               17
# sodium                 87
# potassium              88
# hemoglobin             52
# packed_cell_volume     70
# wbc_cnt               105
# rbc_cnt               130
# htn                     2
# diabetes                2
# CAD                     2
# apetite                 1
# pedal_edema             1
# anemia                  1
# class                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                   object
# BP                    object
# specific_gravity      object
# Albumin               object
# sugar                 object
# RBC                   object
# PC                    object
# PCC                   object
# bacteria              object
# Blood_Gluc_rand       object
# Blood_Urea            object
# Serum_Cr              object
# sodium                object
# potassium             object
# hemoglobin            object
# packed_cell_volume    object
# wbc_cnt               object
# rbc_cnt               object
# htn                   object
# diabetes              object
# CAD                   object
# apetite               object
# pedal_edema           object
# anemia                object
# class                 object
# dtype: object

# %%
df['Age'] = df['Age'].fillna(0).astype(int)

# %%
df.dtypes
# Out:
# Age                    int32
# BP                    object
# specific_gravity      object
# Albumin               object
# sugar                 object
# RBC                   object
# PC                    object
# PCC                   object
# bacteria              object
# Blood_Gluc_rand       object
# Blood_Urea            object
# Serum_Cr              object
# sodium                object
# potassium             object
# hemoglobin            object
# packed_cell_volume    object
# wbc_cnt               object
# rbc_cnt               object
# htn                   object
# diabetes              object
# CAD                   object
# apetite               object
# pedal_edema           object
# anemia                object
# class                 object
# dtype: object

# %%
df['Age']=df['Age'].replace(0, np.mean(df['Age']))

# %%
df.describe()
# Out:
#               Age
# count  400.000000
# mean    51.457313
# std     16.975838
# min      2.000000
# 25%     42.000000
# 50%     54.000000
# 75%     64.000000
# max     90.000000

# %%
df['BP'] = df['BP'].fillna(0).astype(int)

# %%
df['BP']=df['BP'].replace(0, np.mean(df['BP']))

# %%
df
# Out:
#       Age       BP specific_gravity Albumin sugar       RBC        PC  \
# 0    48.0   80.000             1.02       1     0       NaN    normal
# 1     7.0   50.000             1.02       4     0       NaN    normal
# 2    62.0   80.000             1.01       2     3    normal    normal
# 3    48.0   70.000            1.005       4     0    normal  abnormal
# 4    51.0   80.000             1.01       2     0    normal    normal
# 5    60.0   90.000            1.015       3     0       NaN       NaN
# 6    68.0   70.000             1.01       0     0       NaN    normal
# 7    24.0   74.175            1.015       2     4    normal  abnormal
# 8    52.0  100.000            1.015       3     0    normal  abnormal
# 9    53.0   90.000             1.02       2     0  abnormal  abnormal
# 10   50.0   60.000             1.01       2     4       NaN  abnormal
# 11   63.0   70.000             1.01       3     0  abnormal  abnormal
# ...

# %%
df['RBC'].fillna(method='ffill',inplace=True)

# %%
df['RBC'].fillna(method='bfill',inplace=True)

# %%
df['PC'].fillna(method='ffill',inplace=True)
df['PCC'].fillna(method='ffill',inplace=True)
df['bacteria'].fillna(method='ffill',inplace=True)
df['specific_gravity'].fillna(method='ffill',inplace=True)
df['anemia'].fillna(method='ffill',inplace=True)
df['pedal_edema'].fillna(method='ffill',inplace=True)
df['apetite'].fillna(method='ffill',inplace=True)
df['CAD'].fillna(method='ffill',inplace=True)
df['diabetes'].fillna(method='ffill',inplace=True)
df['htn'].fillna(method='ffill',inplace=True)
df['Albumin'].fillna(method='ffill',inplace=True)

# %%
df['sugar'].fillna(method='ffill',inplace=True)

# %%
df.isna().sum()
# Out:
# Age                     0
# BP                      0
# specific_gravity        0
# Albumin                 0
# sugar                   0
# RBC                     0
# PC                      0
# PCC                     0
# bacteria                0
# Blood_Gluc_rand        44
# Blood_Urea             19
# Serum_Cr               17
# sodium                 87
# potassium              88
# hemoglobin             52
# packed_cell_volume     70
# wbc_cnt               105
# rbc_cnt               130
# htn                     0
# diabetes                0
# CAD                     0
# apetite                 0
# pedal_edema             0
# anemia                  0
# class                   0
# dtype: int64

# %%
df['Blood_Gluc_rand'] = df['Blood_Gluc_rand'].fillna(0).astype(int)
df['Blood_Gluc_rand']=df['Blood_Gluc_rand'].replace(0, np.mean(df['Blood_Gluc_rand']))

df['Blood_Urea'] = df['Blood_Urea'].fillna(0).astype(float)
df['Blood_Urea']=df['Blood_Urea'].replace(0, np.mean(df['Blood_Urea']))

df['Serum_Cr'] = df['Serum_Cr'].fillna(0).astype(float)
df['Serum_Cr']=df['Serum_Cr'].replace(0, np.mean(df['Serum_Cr']))

df['sodium'] = df['sodium'].fillna(0).astype(float)
df['sodium']=df['sodium'].replace(0, np.mean(df['sodium']))

df['potassium'] = df['potassium'].fillna(0).astype(float)
df['potassium']=df['potassium'].replace(0, np.mean(df['potassium']))

df['hemoglobin'] = df['hemoglobin'].fillna(0).astype(float)
df['hemoglobin']=df['hemoglobin'].replace(0, np.mean(df['hemoglobin']))


df['packed_cell_volume'] = df['packed_cell_volume'].fillna(0).astype(float)
df['packed_cell_volume']=df['packed_cell_volume'].replace(0, np.mean(df['packed_cell_volume']))

df['wbc_cnt'] = df['wbc_cnt'].fillna(0).astype(int)
df['wbc_cnt']=df['wbc_cnt'].replace(0, np.mean(df['wbc_cnt']))

df['rbc_cnt'] = df['rbc_cnt'].fillna(0).astype(int)
df['rbc_cnt']=df['rbc_cnt'].replace(0, np.mean(df['rbc_cnt']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-0baa4545a2ea> in <module>()
#      18
#      19
# ---> 20 df['packed_cell_volume'] = df['packed_cell_volume'].fillna(0).astype(float)
#      21 df['packed_cell_volume']=df['packed_cell_volume'].replace(0, np.mean(df['packed_cell_volume']))
#      22
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
df['packed_cell_volume']=df['packed_cell_volume'].replace('?', np.nan)

# %%
df['packed_cell_volume']
# Out:
# 0       44
# 1       38
# 2       31
# 3       32
# 4       35
# 5       39
# 6       36
# 7       44
# 8       33
# 9       29
# 10      28
# 11      32
# 12      28
# 13     NaN
# 14      16
# 15      24
# 16     NaN
# 17     NaN
# 18      37
# 19      30
# 20      24
# 21      32
# 22      32
# 23     NaN
# 24      39
# 25      29
# 26      35
# 27      37
# 28     NaN
# 29      38
#       ...
# 370     50
# 371     51
# 372     52
# 373     47
# 374     40
# 375     48
# 376     53
# 377     49
# 378     42
# 379     50
# 380     54
# 381     40
# 382     51
# 383     49
# 384     42
# 385     52
# 386     43
# 387     50
# 388     46
# 389     52
# 390     52
# 391     44
# 392     46
# 393     54
# 394     45
# 395     47
# 396     54
# 397     49
# 398     51
# 399     53
# Name: packed_cell_volume, Length: 400, dtype: object

# %%
df.to_csv('chronic_cleaned.csv')

# %%
df_n=pd.read_csv('chronic_cleaned.csv')

# %%
df_n['packed_cell_volume'] = df_n['packed_cell_volume'].fillna(0).astype(float)
df_n['packed_cell_volume']=df_n['packed_cell_volume'].replace(0, np.mean(df_n['packed_cell_volume']))

df_n['wbc_cnt'] = df_n['wbc_cnt'].fillna(0).astype(int)
df_n['wbc_cnt']=df_n['wbc_cnt'].replace(0, np.mean(df_n['wbc_cnt']))

df_n['rbc_cnt'] = df_n['rbc_cnt'].fillna(0).astype(int)
df_n['rbc_cnt']=df_n['rbc_cnt'].replace(0, np.mean(df_n['rbc_cnt']))

# %%
df_n.isna().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# BP                    0
# specific_gravity      0
# Albumin               0
# sugar                 0
# RBC                   0
# PC                    0
# PCC                   0
# bacteria              0
# Blood_Gluc_rand       0
# Blood_Urea            0
# Serum_Cr              0
# sodium                0
# potassium             0
# hemoglobin            0
# packed_cell_volume    0
# wbc_cnt               0
# rbc_cnt               0
# htn                   0
# diabetes              0
# CAD                   0
# apetite               0
# pedal_edema           0
# anemia                0
# class                 0
# dtype: int64

# %%
df_n.to_csv('chronic_full_cleaned.csv')
